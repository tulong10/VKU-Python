# %%
st = int(input("Enter a number:"))
Dict = {}
for i in range (1,st+1):
    Dict[i] = i*i
for x , y in Dict.items():
    print (x,":",y)
# Out:
# Enter a number: 8
# 1 : 1
# 2 : 4
# 3 : 9
# 4 : 16
# 5 : 25
# 6 : 36
# 7 : 49
# 8 : 64
