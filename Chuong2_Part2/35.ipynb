# %%
st = input ("Nhập 1 danh sách số:")
nums = st.split()
lis = []
for i in nums:
    if int(i) % 2!=0:
        lis.append(i)
print ("Danh sách số lẽ:",lis)
# Out:
# Nhập 1 danh sách số: 1 2 3 4 5
# Danh sách số lẽ: ['1', '3', '5']
