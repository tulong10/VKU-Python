# %%
my_str = input("Enter a string :")
ds_tu = my_str.split()
ds_tu.sort()
tu = list(ds_tu)
print (tu)
# Out:
# Enter a string : Toi ten la Truong Tu Long
# ['Long', 'Toi', 'Truong', 'Tu', 'la', 'ten']
