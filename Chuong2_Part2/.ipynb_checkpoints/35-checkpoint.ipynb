# %%
st = input ("Nhập 1 danh sách số:")
nums = st.split()
lis = []
for i in st:
    if int(st % 2)!=0:
        lis.append(i)
print ("Danh sách số lẽ:",lis)
# Out:
# Nhập 1 danh sách số: 2 3 4 5 6 7
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 st = int(input ("Nhập 1 danh sách số:"))
#       2 lis = {}
#       3 for i in st:
#
# ValueError: invalid literal for int() with base 10: '2 3 4 5 6 7'
