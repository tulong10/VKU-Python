# %%
str = input("Enter a string number:")
chuoi_so= str.split()
Sum =0
AVG =0
for i in chuoi_so:
    Sum += float(i)
AVG = Sum / len(chuoi_so)
print ("Average:",AVG)
# Out:
#   Cell In[2], line 5
#     for i in range chuoi_so:
#                    ^
# SyntaxError: invalid syntax
