# %%
st = input("Enter a string:")
Sum_upper = 0
Sum_lower = 0
for i in st:
    if i.isupper ():
        Sum_upper +=1
    elif i.islower ():
        Sum_lower +=1
    else:
        pass
print ("Sum upper is: ",Sum_upper)
print ("Sum lower is: ".Sum_lower)
# Out:
# Enter a string: Truong Tu Long
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 11
#       9     else:
#      10         pass
# ---> 11 print ("Sum upper is: "+Sum_upper)
#      12 print ("Sum lower is: "+Sum_lower)
#
# TypeError: can only concatenate str (not "int") to str
