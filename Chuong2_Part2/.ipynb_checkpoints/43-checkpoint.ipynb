# %%
def SS ():
    str1 = input("Nhap chhuoi 1:")
    str2 = input("Nhap chuoi 2:")
    if len(str1) > len(str2):
        print ("Chuoi dai hon la:",str1)
    elif len(str1)  < len (str2):
        print ("Chuoi dai hon la:",str2)
    else:
        print ("Hai chuoi deu bang nhau:", str2,"-",str1)

SS()
# Out:
# Nhap chhuoi 1: Long
# Nhap chuoi 2: Hung
# Hai chuoi deu bang nhau: Hung - Long
