# %%
from math import *
def NT (x):
    if x  <= 1:
        return False
    for i in range (2, int(math.sqrt(x)) +1):
        if x% i ==0:
            return False
    return True
num = int(input("Nhap mot so can kiem tra:"))
if NT(num):
    print (num," La so nguyen to:")
else:
    print (num," Khong phai la so nguyen to:")
# Out:
# Nhap mot so can kiem tra: 3
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 10
#       8     return True
#       9 num = int(input("Nhap mot so can kiem tra:"))
# ---> 10 if NT(num):
#      11     print (num," La so nguyen to:")
#      12 else:
#
# Cell In[6], line 5, in NT(x)
#       3 if x  <= 1:
#       4     return False
# ----> 5 for i in range (2, math.sqrt(x) +1):
#       6     if x% i ==0:
#       7         return False
#
# NameError: name 'math' is not defined
