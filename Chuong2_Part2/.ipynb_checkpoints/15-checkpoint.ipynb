# %%
str = input("Enter some values:")
ds = str.split(" ")
tupple = tuple(ds)
print (ds)
print (tupple)
# Out:
# Enter some values: 30 31 32 34 45 67
# ['30 31 32 34 45 67 ']
# ('30 31 32 34 45 67 ',)
