# %%
my_str = input("Enter a string :")
ds_tu = my_str.spit()
ds_tu.sort()
tu = list(ds_tu)
print (tu)
# Out:
# Enter a string : Toi ten la Truong Tu Long
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 2
#       1 my_str = input("Enter a string :")
# ----> 2 ds_tu = my_str.spit()
#       3 ds_tu.sort()
#       4 tu = list(ds_tu)
#
# AttributeError: 'str' object has no attribute 'spit'
