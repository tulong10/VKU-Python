# %%
def TB(x1, x2, x3):
    return (x1 + x2 + x3) / 3  
a = int(input("Enter number 1: "))
b = int(input("Enter number 2: "))
c = int(input("Enter number 3: "))

AVG  = TB(a, b, c)  
print("Average is:",AVG)
# Out:
# Enter number 1:  4
# Enter number 2:  5
# Enter number 3:  6
# Average is: 5.0
