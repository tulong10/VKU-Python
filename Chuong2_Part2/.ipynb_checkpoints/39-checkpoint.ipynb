# %%
st = int(input("Enter a number:"))
Dict = dict{}
for i in range (i,st+1):
    Dict[i] = i*i
for x , y in Dict.itemse():
    print (x,":",y)
# Out:
#   Cell In[1], line 2
#     Dict = dict{}
#                ^
# SyntaxError: invalid syntax
