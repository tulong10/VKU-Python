# %%
Lis =[]
while True:
    st = int (input("Nhập một số nguyên:"))
    if st == 0:
        break
    Lis.append(st)
Lis.sort()
for n in Lis:
   print(n)
# Out:
# Nhập một số nguyên: 1
# Nhập một số nguyên: 2
# Nhập một số nguyên: -1
# Nhập một số nguyên: -10
# Nhập một số nguyên: 10
# Nhập một số nguyên: 0
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 8
#       6     Lis.append(st)
#       7 Lis.sort()
# ----> 8 for n in List:
#       9    print(n)
#
# NameError: name 'List' is not defined
