# %%
Lis =[]
while True:
    st = int(input("Enter a number:"))
    if st == 0:
        break
    Lis.append(st)
Lis.sort()
print (Lis)
# Out:
# Enter a number: 1
# Enter a number: 2
# Enter a number: 3
# Enter a number: 4
# Enter a number: 5
# Enter a number: 6
# Enter a number: 0
# [1, 2, 3, 4, 5, 6]
