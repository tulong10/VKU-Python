# %%
Lis =[]
while True:
    st = input("Nhập một số nguyên:")
    if st == "":
        break
    Lis.append(int(st))
Lis.sort()
for n in Lis:
   print(n)
# Out:
# Nhập một số nguyên: 1
# Nhập một số nguyên: 2
# Nhập một số nguyên: 3
# Nhập một số nguyên: 4
# Nhập một số nguyên: -10
# Nhập một số nguyên: 0
# Nhập một số nguyên: -5
# Nhập một số nguyên:
# -10
# -5
# 0
# 1
# 2
# 3
# 4
