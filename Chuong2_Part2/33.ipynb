# %%
text = input("Nhập chuỗi cần kiểm tra: ")
reversed_text = text[::-1] # [::-1] dùng để đảo ngược chuỗi
if text == reversed_text:
    print("Đây là Palindrome ")
else:
    print("Không phải Palindrome ")
# Out:
# Nhập chuỗi cần kiểm tra:  heeh
# Đây là Palindrome
