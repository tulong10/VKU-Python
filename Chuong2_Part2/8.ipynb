# %%
st1 = """!()-[]{};:""\,<>./?@#$%^&*_~"""
st = input("Enter a string")
st2 =""
for char in st:
    if char not in st1:
        st2 += char
print (st2)
# Out:
# Enter a string Toi!() ten la Truong Tu Long@#$
# Toi ten la Truong Tu Long
