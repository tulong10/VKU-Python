# %%
Lis = []
while True:
    st = input ("Nhập vào 1 từ:")
    if st == "":
        break
    if st not in Lis:
        Lis.append(st)
print ("Các từ sau khi loại bỏ trùng lặp là :")
for i in Lis:
    print (i)
# Out:
# Nhập vào 1 từ: Long
# Nhập vào 1 từ: python
# Nhập vào 1 từ: java
# Nhập vào 1 từ: php
# Nhập vào 1 từ: php
# Nhập vào 1 từ: Long
# Nhập vào 1 từ:
# Các từ sau khi loại bỏ trùng lặp là :
# Long
# python
# java
# php
