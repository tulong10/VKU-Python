# %%
x = int (input("Nhập số cần tính giai thừa:"))
def giaithua(x):
    if x==0:
        return 1
    return x * (giaithua(x -1))
print (" Giai thua cua ",x, "la:", giaithua(x))
# Out:
# Nhập số cần tính giai thừa: 3
#  Giai thua cua  3 la: 6
