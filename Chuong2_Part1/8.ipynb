# %%
from math import *
a = int(input ("Enter a edge length of triangle: "))
S = (sqrt(3)/4)*float(a)**2
print ("Area of the triangle is: ", S)
# Out:
# Enter a edge length of triangle:  5
# Area of the triangle is:  10.825317547305483
