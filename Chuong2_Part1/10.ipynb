# %%
width = float(input("Nhập chiểu rộng:"))
# Out:
# Nhập chiểu rộng: 120

# %%
length = float(input("Nhập chiều dài:"))
# Out:
# Nhập chiều dài: 50

# %%
S= width * length

# %%
print ("Diện tích căn phòng là:", S)
# Out:
# Diện tích căn phòng là: 6000.0
