# %%
from math import*

# %%
r = int(input(" Nhap ban kinh:"))
# Out:
#  Nhap ban kinh: 2

# %%
h = int(input(" Nhap chieu cao:"))
# Out:
#  Nhap chieu cao: 10

# %%
V = int(pi * r**2 * h)

# %%
print ("V=",V)
# Out:
# V= 125
