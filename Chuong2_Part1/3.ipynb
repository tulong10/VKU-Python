# %%
data =" longtt.24ns@vku.udn.vn_Thua_Thien_Hue"

# %%
Start_Position = data.find("@")

# %%
End_position = data.find("_", Start_Position)

# %%
host = data[Start_Position +1 :End_position]

# %%
print (host)
# Out:
# vku.udn.vn
