# %%
meal_cost = float(input("Nhập chi phí bữa ăn: "))


tax = meal_cost * 0.05
tip = meal_cost * 0.18
total = meal_cost + tax + tip


print("Tiền bữa ăn:", meal_cost)
print("Thuế:", tax)
print("Tiền boa:", tip)
print("Tổng cộng:", total)
# Out:
# Nhập chi phí bữa ăn:  20.000
# Tiền bữa ăn: 20.0
# Thuế: 1.0
# Tiền boa: 3.5999999999999996
# Tổng cộng: 24.6
