# %%
import math
a = float(input("Nhập cạnh a: "))
b = float(input("Nhập cạnh b: "))
c = float(input("Nhập cạnh c: "))

A = float(input("Nhập góc A (radian): "))
B = float(input("Nhập góc B (radian): "))
C = float(input("Nhập góc C (radian): "))

S1 = 0.5 * a * b * math.sin(C)
S2 = 0.5 * a * c * math.sin(B)
S3 = 0.5 * b * c * math.sin(A)

print("Diện tích tam giác (theo ab*sinC):", S1)
print("Diện tích tam giác (theo ac*sinB):", S2)
print("Diện tích tam giác (theo bc*sinA):", S3)
# Out:
# Nhập cạnh a:  2
# Nhập cạnh b:  3
# Nhập cạnh c:  4
# Nhập góc A (radian):  20
# Nhập góc B (radian):  10
# Nhập góc C (radian):  25
# Diện tích tam giác (theo ab*sinC): -0.3970552502933191
# Diện tích tam giác (theo ac*sinB): -2.176084443557479
# Diện tích tam giác (theo bc*sinA): 5.477671504365766
