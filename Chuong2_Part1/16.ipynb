# %%
import math

vi = float(input("Nhập vận tốc ban đầu vi (m/s): "))
a = float(input("Nhập gia tốc a (m/s^2): "))
d = float(input("Nhập quãng đường (m): "))

vf = math.sqrt(vi**2 + 2 * a * d)
print("Vận tốc cuối vf (m/s):", vf)
# Out:
# Nhập vận tốc ban đầu vi (m/s):  500
# Nhập gia tốc a (m/s^2):  20
# Nhập quãng đường (m):  10000
# Vận tốc cuối vf (m/s): 806.2257748298549
