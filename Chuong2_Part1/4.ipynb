# %%
data = input("Enter your string")
# Out:
# Enter your string Lập trình Python

# %%
s1 = input("Enter the word that need to replace:")
# Out:
# Enter the word that need to replace: Python

# %%
s2 = input("Enter the word after to replace:")
# Out:
# Enter the word after to replace: Java

# %%
data = data.replace(s1,s2)

# %%
print(data)
# Out:
# Lập trình Java
