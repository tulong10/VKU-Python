# %%
data = input(" Enter your string:")
# Out:
#  Enter your string: aaaaabbbbb

# %%
Frist5_character = data[:5]

# %%
Last5_character = data [-5:]

# %%
Str_inline = 4 * ( data + " ")

# %%
Str_4_inline = 4 * (data + "\n")

# %%
print (" First 5 character are:"+ Frist5_character)
# Out:
#  First 5 character are:aaaaa

# %%
print (" Lats 5 character are:" + Last5_character)
# Out:
#  Lats 5 character are:bbbbb

# %%
print (" Four string of 1 line:"+ Str_inline)
# Out:
#  Four string of 1 line:aaaaabbbbb aaaaabbbbb aaaaabbbbb aaaaabbbbb

# %%
print (" Four string of 4 line:"+ Str_4_inline)
# Out:
#  Four string of 4 line:aaaaabbbbb
# aaaaabbbbb
# aaaaabbbbb
# aaaaabbbbb
