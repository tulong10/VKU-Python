# %%
st = input("Enter your string:")
# Out:
# Enter your string: Truong Tu Long

# %%
print (st.upper())
# Out:
# TRUONG TU LONG

# %%
print (st.title())
# Out:
# Truong Tu Long

# %%
print (st.lower())
# Out:
# truong tu long
